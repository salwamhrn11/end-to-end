# %%
import pandas as pd
import numpy as np

# %%
dataUniversitas = pd.read_csv("pddikti.csv")
dataJob = pd.read_csv("dataJob.csv")

# %%
dataUniversitas
# Out:
#            Provinsi                              web-scraper-start-url  tahun  \
# 0              Aceh  https://www.bps.go.id/indikator/indikator/view...   2022
# 1    Sumatera Utara  https://www.bps.go.id/indikator/indikator/view...   2022
# 2    Sumatera Barat  https://www.bps.go.id/indikator/indikator/view...   2022
# 3              Riau  https://www.bps.go.id/indikator/indikator/view...   2022
# 4             Jambi  https://www.bps.go.id/indikator/indikator/view...   2022
# ..              ...                                                ...    ...
# 100          Maluku                                                NaN   2020
# 101    Maluku Utara                                                NaN   2020
# 102     Papua Barat                                                NaN   2020
# 103           Papua                                                NaN   2020
# 104       Indonesia                                                NaN   2020
#
# ...

# %%
dataUniversitas = dataUniversitas[~dataUniversitas['tahun'].isin([2020, 2021])]

# %%
dataUniversitas
# Out:
#                      Provinsi  \
# 0                        Aceh
# 1              Sumatera Utara
# 2              Sumatera Barat
# 3                        Riau
# 4                       Jambi
# 5            Sumatera Selatan
# 6                    Bengkulu
# 7                     Lampung
# 8   Kepulauan Bangka Belitung
# 9              Kepulauan Riau
# 10                DKI Jakarta
# 11                 Jawa Barat
# 12                Jawa Tengah
# 13              DI Yogyakarta
# 14                 Jawa Timur
# 15                     Banten
# 16                       Bali
# 17        Nusa Tenggara Barat
# 18        Nusa Tenggara Timur
# 19           Kalimantan Barat
# 20          Kalimantan Tengah
# 21         Kalimantan Selatan
# 22           Kalimantan Timur
# 23           Kalimantan Utara
# 24             Sulawesi Utara
# 25            Sulawesi Tengah
# 26           Sulawesi Selatan
# 27          Sulawesi Tenggara
# 28                  Gorontalo
# 29             Sulawesi Barat
# ...

# %%
dataJob
# Out:
#                                                 job_url      site  \
# 0     https://id.indeed.com/viewjob?jk=1159052ece6ee2c8    indeed
# 1     https://id.indeed.com/viewjob?jk=22377052ba8e1c24    indeed
# 2     https://id.indeed.com/viewjob?jk=88e1904d38e58ffe    indeed
# 3     https://id.indeed.com/viewjob?jk=5430a1eb2d7b30e6    indeed
# 4     https://id.indeed.com/viewjob?jk=26c56b898894edb1    indeed
# ...                                                 ...       ...
# 1266      https://www.linkedin.com/jobs/view/3745973218  linkedin
# 1267      https://www.linkedin.com/jobs/view/3729433484  linkedin
# 1268      https://www.linkedin.com/jobs/view/3683622995  linkedin
# 1269      https://www.linkedin.com/jobs/view/3759208408  linkedin
# 1270      https://www.linkedin.com/jobs/view/3752392853  linkedin
#
#                                             title  \
# 0                                  Data Scientist
# 1                                       Scientist
# ...

# %%
#replace jd jawa barat
dataJob['location'].replace(['Bandung, JB, Indonesia','Bekasi, JB, Indonesia','Depok, JB, Indonesia','JB, Indonesia','JB, Indonesia','Karawang, JB, Indonesia'], 'Jawa Barat', inplace=True)

#replace jd jawa tengah
dataJob['location'].replace(['Salatiga, JT, Indonesia','Surakarta, JT, Indonesia'], 'Jawa Tengah', inplace=True)

#replace jadi di yogyakarta
dataJob['location'].replace(['Bantul, YO, Indonesia','Yogyakarta, YO, Indonesia','Yogyakarta, Indonesia'], 'DI Yogyakarta', inplace=True)

#replace jadi jawa timur
dataJob['location'].replace(['Gresik, JI, Indonesia','JI, Indonesia','Malang, JI, Indonesia','Surabaya, JI, Indonesia'], 'Jawa Timur', inplace=True)

#replace jadi bali
dataJob['location'].replace(['Bali, Indonesia','Badung, BA, Indonesia','BA, Indonesia','Denpasar, BA, Indonesia','Kuta, BA, Indonesia'], 'Bali', inplace=True)

#replace jadi kalimantan timur
dataJob['location'].replace(['Balikpapan, KI, Indonesia'], 'Kalimantan Timur', inplace=True)

#replace jadi kalimantan selatan
dataJob['location'].replace(['Banjarmasin, KS, Indonesia','KS, Indonesia'], 'Kalimantan Selatan', inplace=True)

#replace jadi kepulauan riau
dataJob['location'].replace(['Batam, KR, Indonesia'], 'Kepulauan Riau', inplace=True)

#replace jadi dki jakarta
dataJob['location'].replace(['Jakarta, Indonesia','Jakarta, JK, Indonesia'], 'DKI Jakarta', inplace=True)

#replace jd lampung
dataJob['location'].replace(['LA, Indonesia'], 'Lampung', inplace=True)

#replace jd Banten
dataJob['location'].replace(['Tangerang, BT, Indonesia'], 'Banten', inplace=True)

# %%
fullData = pd.merge(dataJob, dataUniversitas, left_on='location', right_on='Provinsi', how='outer')
fullData.drop(columns=['Provinsi'], axis=1, inplace=True)

# %%
fullData
# Out:
#                                                 job_url    site  \
# 0     https://id.indeed.com/viewjob?jk=1159052ece6ee2c8  indeed
# 1     https://id.indeed.com/viewjob?jk=22377052ba8e1c24  indeed
# 2     https://id.indeed.com/viewjob?jk=88e1904d38e58ffe  indeed
# 3     https://id.indeed.com/viewjob?jk=5430a1eb2d7b30e6  indeed
# 4     https://id.indeed.com/viewjob?jk=26c56b898894edb1  indeed
# ...                                                 ...     ...
# 1289                                                NaN     NaN
# 1290                                                NaN     NaN
# 1291                                                NaN     NaN
# 1292                                                NaN     NaN
# 1293                                                NaN     NaN
#
#                title                       company     location  job_type  \
# 0     Data Scientist                     NielsenIQ  DKI Jakarta  fulltime
# ...

# %%
fullData = fullData.dropna(subset=['location'])
fullData.drop(['benefits', 'emails', 'is_remote', 'currency', 'num_urgent_words', 'job_url', 'web-scraper-start-url'], axis=1, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12604\3545633409.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fullData.drop(['benefits', 'emails', 'is_remote', 'currency', 'num_urgent_words', 'job_url', 'web-scraper-start-url'], axis=1, inplace=True)

# %%
fullData = fullData[fullData['interval'] != 'interval']
fullData.reset_index(drop=True, inplace=True)

# %%
fullData
# Out:
#        site                    title                       company  \
# 0    indeed           Data Scientist                     NielsenIQ
# 1    indeed                Scientist                    DELOS Aqua
# 2    indeed           Data Scientist  Techtiera Services Indonesia
# 3    indeed           Data Scientist                      PGI Data
# 4    indeed           Data Scientist                   Pro Sigmaka
# ..      ...                      ...                           ...
# 707  indeed           Student Intern                   Formulatrix
# 708  indeed            Web Developer              Ozeva Technology
# 709  indeed            Web Developer                      Techarea
# 710  indeed        Android Developer                      Techarea
# 711  indeed  User Interface Designer              Upscalix Pty Ltd
#
#                     location    job_type date_posted interval  min_amount  \
# 0                DKI Jakarta    fulltime  2023-11-03      NaN         NaN
# ...

# %%
lulusanSarjana=pd.read_csv("jumlah lulusan sarjana.csv")
lulusanSMASMK=pd.read_csv("jumlah lulusan sma_smk.csv")
penduduk=pd.read_csv("jumlah penduduk perprovinsi.csv")
pengangguran=pd.read_csv("persentase pengangguran.csv")

# %%
lulusanSarjana
# Out:
#                Provinsi Jumlah lulusan sarjana 2020  \
# 0           DKI Jakarta                     178.329
# 1            Jawa Barat                     192.643
# 2                Banten                     114.223
# 3           Jawa Tengah                     142.173
# 4         DI Yogyakarta                      88.065
# 5            Jawa Timur                     227.694
# 6                  Aceh                      32.118
# 7        Sumatera Utara                       77.13
# 8        Sumatera Barat                      45.666
# 9                  Riau                      33.425
# 10       Kepulauan Riau                       8.213
# 11                Jambi                      13.336
# 12     Sumatera Selatan                      34.317
# 13      Bangka Belitung                       2.856
# 14             Bengkulu                      13.196
# 15              Lampung                      28.747
# 16     Kalimantan Barat                      21.209
# ...

# %%
lulusanSMASMK
# Out:
#                Provinsi Persentase lulusan SMA/SMK 2020  \
# 0                  Aceh                           70,07
# 1                  Bali                           74,88
# 2       Bangka Belitung                           56,74
# 3                Banten                           64,24
# 4              Bengkulu                           62,73
# 5         DI Yogyakarta                           87,99
# 6           DKI Jakarta                           85,67
# 7             Gorontalo                           55,35
# 8             Indonesia                           63,95
# 9                 Jambi                           63,66
# 10           Jawa Barat                           63,56
# 11          Jawa Tengah                           55,82
# 12           Jawa Timur                           63,53
# 13     Kalimantan Barat                           55,23
# 14   Kalimantan Selatan                           63,05
# 15    Kalimantan Tengah                           60,77
# ...

# %%
penduduk
# Out:
#                Provinsi Jumlah penduduk perprovinsi 2020  \
# 0                  Aceh                          5.274,9
# 1                  Bali                          4.317,4
# 2       Bangka Belitung                          1.455,7
# 3                Banten                         11.904,6
# 4              Bengkulu                          2.010,7
# 5         DI Yogyakarta                          3.668,7
# 6           DKI Jakarta                         10.562,1
# 7             Gorontalo                          1.171,7
# 8             Indonesia                        270.203,9
# 9                 Jambi                          3.548,2
# 10           Jawa Barat                         48.274,2
# 11          Jawa Tengah                         36.516,0
# 12           Jawa Timur                         40.665,7
# 13     Kalimantan Barat                          5.414,4
# 14   Kalimantan Selatan                          4.073,6
# ...

# %%
pengangguran
# Out:
#                Provinsi Persentase pengangguran 2020  \
# 0                  Aceh                         6,59
# 1                  Bali                         5,63
# 2       Bangka Belitung                         5,25
# 3                Banten                        10,64
# 4              Bengkulu                         4,07
# 5         DI Yogyakarta                         4,57
# 6           DKI Jakarta                        10,95
# 7             Gorontalo                         4,28
# 8             Indonesia                         7,07
# 9                 Jambi                         5,13
# 10           Jawa Barat                        10,46
# 11          Jawa Tengah                         6,48
# 12           Jawa Timur                         5,84
# 13     Kalimantan Barat                         5,81
# 14   Kalimantan Selatan                         4,74
# 15    Kalimantan Tengah                         4,58
# 16     Kalimantan Timur                         6,87
# ...

# %%
#merge lulusan sarjana
fullData = pd.merge(fullData, lulusanSarjana, left_on='location', right_on='Provinsi', how='outer')
fullData.drop(columns=['Provinsi'], axis=1, inplace=True)

# %%
#merge lulusan sma/smk
fullData = pd.merge(fullData, lulusanSMASMK, left_on='location', right_on='Provinsi', how='outer')
fullData.drop(columns=['Provinsi'], axis=1, inplace=True)

# %%
#merge jumlah penduduk
fullData = pd.merge(fullData, penduduk, left_on='location', right_on='Provinsi', how='outer')
fullData.drop(columns=['Provinsi'], axis=1, inplace=True)

# %%
#merge persentase pengangguran
fullData = pd.merge(fullData, pengangguran, left_on='location', right_on='Provinsi', how='outer')
fullData.drop(columns=['Provinsi'], axis=1, inplace=True)

# %%
fullData
# Out:
#        site           title                       company     location  \
# 0    indeed  Data Scientist                     NielsenIQ  DKI Jakarta
# 1    indeed       Scientist                    DELOS Aqua  DKI Jakarta
# 2    indeed  Data Scientist  Techtiera Services Indonesia  DKI Jakarta
# 3    indeed  Data Scientist                      PGI Data  DKI Jakarta
# 4    indeed  Data Scientist                   Pro Sigmaka  DKI Jakarta
# ..      ...             ...                           ...          ...
# 799     NaN             NaN                           NaN          NaN
# 800     NaN             NaN                           NaN          NaN
# 801     NaN             NaN                           NaN          NaN
# 802     NaN             NaN                           NaN          NaN
# 803     NaN             NaN                           NaN          NaN
#
#      job_type date_posted interval  min_amount  max_amount  \
# ...

# %%
fullData.columns
# Out:
# Index(['site', 'title', 'company', 'location', 'job_type', 'date_posted',
#        'interval', 'min_amount', 'max_amount', 'description', 'tahun',
#        'Jumlah Perguruan Tinggi di Bawah Kementerian Riset, Teknologi dan Pendidikan Tinggi',
#        'Jumlah Mahasiswa di Bawah Kementerian Riset, Teknologi dan Pendidikan Tinggi',
#        'Jumlah lulusan sarjana 2020', 'Jumlah lulusan sarjana 2021',
#        'Persentase lulusan SMA/SMK 2020', 'Persentase lulusan SMA/SMK 2021',
#        'Jumlah penduduk perprovinsi 2020', 'Jumlah penduduk perprovinsi 2021',
#        'Persentase pengangguran 2020', 'Persentase pengangguran 2021'],
#       dtype='object')

# %%
fixData=fullData[['site','title','company','location', 'description','Jumlah Perguruan Tinggi di Bawah Kementerian Riset, Teknologi dan Pendidikan Tinggi','Jumlah Mahasiswa di Bawah Kementerian Riset, Teknologi dan Pendidikan Tinggi',
       'Jumlah lulusan sarjana 2020', 'Jumlah lulusan sarjana 2021',
       'Persentase lulusan SMA/SMK 2020', 'Persentase lulusan SMA/SMK 2021',
       'Jumlah penduduk perprovinsi 2020', 'Jumlah penduduk perprovinsi 2021',
       'Persentase pengangguran 2020', 'Persentase pengangguran 2021']]

# %%
fixData
# Out:
#        site           title                       company     location  \
# 0    indeed  Data Scientist                     NielsenIQ  DKI Jakarta
# 1    indeed       Scientist                    DELOS Aqua  DKI Jakarta
# 2    indeed  Data Scientist  Techtiera Services Indonesia  DKI Jakarta
# 3    indeed  Data Scientist                      PGI Data  DKI Jakarta
# 4    indeed  Data Scientist                   Pro Sigmaka  DKI Jakarta
# ..      ...             ...                           ...          ...
# 799     NaN             NaN                           NaN          NaN
# 800     NaN             NaN                           NaN          NaN
# 801     NaN             NaN                           NaN          NaN
# 802     NaN             NaN                           NaN          NaN
# 803     NaN             NaN                           NaN          NaN
#
#                                            description  \
# 0    Working knowledge with data visualization tool...
# ...

# %%
fixData.isna().sum()
# Out:
# site                                                                                    92
# title                                                                                   92
# company                                                                                 92
# location                                                                                92
# description                                                                            115
# Jumlah Perguruan Tinggi di Bawah Kementerian Riset, Teknologi dan Pendidikan Tinggi     98
# Jumlah Mahasiswa di Bawah Kementerian Riset, Teknologi dan Pendidikan Tinggi            98
# Jumlah lulusan sarjana 2020                                                             75
# Jumlah lulusan sarjana 2021                                                             75
# Persentase lulusan SMA/SMK 2020                                                         75
# ...

# %%
fixData.dropna()
# Out:
#        site              title                                    company  \
# 0    indeed     Data Scientist                                  NielsenIQ
# 1    indeed          Scientist                                 DELOS Aqua
# 2    indeed     Data Scientist               Techtiera Services Indonesia
# 3    indeed     Data Scientist                                   PGI Data
# 4    indeed     Data Scientist                                Pro Sigmaka
# ..      ...                ...                                        ...
# 704  indeed  Software Engineer  PT Promanufacture Indonesia (Formulatrix)
# 705  indeed  Software Engineer                                Formulatrix
# 706  indeed  Software Engineer                                Formulatrix
# 707  indeed     Student Intern                                Formulatrix
# 708  indeed      Web Developer                           Ozeva Technology
#
#         location                                        description  \
# ...

# %%
site                                                                                    object
title                                                                                   object
company                                                                                 object
location                                                                                object
description                                                                             object
Jumlah Perguruan Tinggi di Bawah Kementerian Riset, Teknologi dan Pendidikan Tinggi    float64
Jumlah Mahasiswa di Bawah Kementerian Riset, Teknologi dan Pendidikan Tinggi           float64
Jumlah lulusan sarjana 2020                                                             object
Jumlah lulusan sarjana 2021                                                             object
Persentase lulusan SMA/SMK 2020                                                         object
Persentase lulusan SMA/SMK 2021                                                         object
Jumlah penduduk perprovinsi 2020                                                        object
Jumlah penduduk perprovinsi 2021                                                        object
Persentase pengangguran 2020                                                            object
Persentase pengangguran 2021                                                            object

# %%
fixData.to_csv('fixData.csv', index=False)

# %%
fixData.dtypes
# Out:
# site                                                                                    object
# title                                                                                   object
# company                                                                                 object
# location                                                                                object
# description                                                                             object
# Jumlah Perguruan Tinggi di Bawah Kementerian Riset, Teknologi dan Pendidikan Tinggi    float64
# Jumlah Mahasiswa di Bawah Kementerian Riset, Teknologi dan Pendidikan Tinggi           float64
# Jumlah lulusan sarjana 2020                                                             object
# Jumlah lulusan sarjana 2021                                                             object
# Persentase lulusan SMA/SMK 2020                                                         object
# ...
